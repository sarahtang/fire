# %%
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import timedelta

# %%
viirs = pd.read_csv("fire_nrt_V1_83401.csv")
# modis = pd.read_csv("fire_nrt_M6_83400.csv")

# %%
viirs.head()
# Out:
#    latitude  longitude  bright_ti4  scan  track    acq_date  acq_time  \
# 0  33.03452  -83.08730       318.6  0.32   0.55  2019-07-01       636
# 1  34.63658  -87.09289       304.2  0.56   0.69  2019-07-01       636
# 2  34.63654  -87.08815       304.2  0.56   0.69  2019-07-01       636
# 3  34.34694  -82.77595       306.3  0.32   0.54  2019-07-01       636
# 4  43.24686  -70.96125       301.8  0.39   0.36  2019-07-01       636
#
#   satellite instrument confidence version  bright_ti5  frp daynight
# 0         N      VIIRS          n  1.0NRT       288.2  0.9        N
# 1         N      VIIRS          n  1.0NRT       286.8  1.0        N
# 2         N      VIIRS          n  1.0NRT       287.2  1.9        N
# 3         N      VIIRS          n  1.0NRT       291.0  0.8        N
# 4         N      VIIRS          n  1.0NRT       285.4  0.6        N

# %%
# modis.head()

# %%
# modis = modis.rename(columns = {"bright_t31": "channel_brightness"})
# viirs = viirs.rename(columns = {"bright_ti5": "channel_brightness"})

# %%
# viirs = viirs.rename(columns = {"bright_ti4": "brightness"})

# %%
# firedata = pd.concat([viirs, modis])

# %%
# firedata = firedata.reset_index()

# %%
# firedata = firedata.drop(columns = "index")

# %%
# type(firedata['acq_date'][1])

# %%
viirs['acq_date'] = viirs['acq_date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))

# %%
viirs.head()
# Out:
#    latitude  longitude  bright_ti4  scan  track   acq_date  acq_time  \
# 0  33.03452  -83.08730       318.6  0.32   0.55 2019-07-01       636
# 1  34.63658  -87.09289       304.2  0.56   0.69 2019-07-01       636
# 2  34.63654  -87.08815       304.2  0.56   0.69 2019-07-01       636
# 3  34.34694  -82.77595       306.3  0.32   0.54 2019-07-01       636
# 4  43.24686  -70.96125       301.8  0.39   0.36 2019-07-01       636
#
#   satellite instrument confidence version  bright_ti5  frp daynight
# 0         N      VIIRS          n  1.0NRT       288.2  0.9        N
# 1         N      VIIRS          n  1.0NRT       286.8  1.0        N
# 2         N      VIIRS          n  1.0NRT       287.2  1.9        N
# 3         N      VIIRS          n  1.0NRT       291.0  0.8        N
# 4         N      VIIRS          n  1.0NRT       285.4  0.6        N

# %%
# Viirs in North America
viirs_na = viirs[(viirs.latitude <= 50) &
                 (viirs.latitude >= 28) &
                 (viirs.longitude <= -60) &
                 (viirs.longitude >= -130)]
viirs_na.head()
len(viirs_na)
# Out:
# 143937

# %%
len(viirs)
# Out:
# 239299

# %%
len(viirs.groupby(['latitude']))
# Out:
# 208360

# %%
len(viirs.groupby(['longitude']))
# Out:
# 217639

# %%
# Created smaller sample to test with
viirs_test = viirs[(viirs.latitude <= 50) &
                 (viirs.latitude >= 48) &
                 (viirs.longitude <= -120) &
                 (viirs.longitude >= -121)]
len(viirs_test)
# Out:
# 122

# %%
viirs_test.head()
viirs_test
viirs_test = viirs_test.reset_index()
viirs_test = viirs_test.drop(columns="index")

# %%
viirs_test['acq_date'].value_counts(sort=False)
# Out:
# 2019-09-21     1
# 2019-08-21     5
# 2019-08-09     7
# 2019-10-29     1
# 2019-08-28     4
# 2019-09-04     2
# 2019-08-06     6
# 2019-08-01     4
# 2019-08-08    22
# 2019-08-27     3
# 2019-07-27     6
# 2019-09-03     3
# 2019-10-23     1
# 2019-08-29    14
# 2019-09-05     1
# 2019-07-24     1
# 2019-07-31     7
# 2019-09-07     3
# 2019-08-07    20
# 2019-09-26     3
# 2019-09-02     3
# 2019-08-02     5
# Name: acq_date, dtype: int64

# %%
# Test
# Determine chunks of consecutive days in dataset
dt = viirs_test['acq_date']
day = pd.Timedelta('1d')
# TODO need to check for multiple rows shift
in_block = ((dt - dt.shift(-1)).abs() == day) | (dt.diff() == day)
in_block

filt = viirs_test.loc[in_block]
breaks = filt['acq_date'].diff() != day
groups = breaks.cumsum()
groups

# for _, frame in filt.groupby(groups):
#     print(frame, end='\n\n')
    
viirs_test['groups'] = groups
viirs_test
# Out:
#      latitude  longitude  bright_ti4  scan  track   acq_date  acq_time  \
# 0    48.04707 -120.46503       296.9  0.43   0.62 2019-07-24      1106
# 1    48.26446 -120.72204       295.8  0.39   0.36 2019-07-27      1012
# 2    48.26529 -120.72690       324.0  0.39   0.36 2019-07-27      1012
# 3    48.26204 -120.72818       326.8  0.39   0.36 2019-07-27      1012
# 4    48.26120 -120.72330       314.4  0.39   0.36 2019-07-27      1012
# 5    48.26409 -120.73034       346.3  0.34   0.56 2019-07-27      2136
# 6    48.26329 -120.72844       336.1  0.34   0.56 2019-07-27      2136
# 7    48.26039 -120.72485       295.5  0.39   0.44 2019-07-31      1036
# 8    48.53847 -120.22054       367.0  0.69   0.74 2019-07-31      2200
# 9    48.53862 -120.23101       350.4  0.69   0.74 2019-07-31      2200
# 10   48.53596 -120.23206       343.5  0.69   0.74 2019-07-31      2200
# 11   48.54295 -120.23227       339.0  0.69   0.74 2019-07-31      2200
# 12   48.53574 -120.22076       367.0  0.69   0.74 2019-07-31      2200
# 13   48.54277 -120.22243       367.0  0.69   0.74 2019-07-31      2200
# 14   48.25742 -120.72633       297.3  0.41   0.37 2019-08-01      1018
# 15   48.26073 -120.72491       305.7  0.41   0.37 2019-08-01      1018
# 16   48.26174 -120.72616       344.1  0.40   0.60 2019-08-01      2142
# 17   48.26184 -120.72263       367.0  0.40   0.60 2019-08-01      2142
# 18   48.26644 -120.73222       306.7  0.40   0.37 2019-08-02       954
# 19   48.26564 -120.72642       322.3  0.40   0.37 2019-08-02       954
# 20   48.26310 -120.73317       311.1  0.40   0.37 2019-08-02       954
# 21   48.25897 -120.72832       315.0  0.40   0.37 2019-08-02       954
# 22   48.25819 -120.72265       303.5  0.40   0.37 2019-08-02       954
# 23   48.26060 -120.72910       296.8  0.45   0.39 2019-08-06      1024
# 3           N      VIIRS          n  1.0NRT       285.9   1.7        N     NaN
# 4           N      VIIRS          n  1.0NRT       282.8   1.7        N     NaN
# 5           N      VIIRS          n  1.0NRT       291.3   3.1        D     NaN
# 6           N      VIIRS          n  1.0NRT       294.7   6.0        D     NaN
# 7           N      VIIRS          n  1.0NRT       280.2   0.7        N     NaN
# 8           N      VIIRS          h  1.0NRT       309.6  53.9        D     NaN
# 9           N      VIIRS          n  1.0NRT       300.0  53.9        D     NaN
# 10          N      VIIRS          n  1.0NRT       297.3  18.8        D     NaN
# 11          N      VIIRS          n  1.0NRT       299.1  30.8        D     NaN
# 12          N      VIIRS          h  1.0NRT       302.4  36.3        D     NaN
# 13          N      VIIRS          h  1.0NRT       303.1  81.1        D     1.0
# 14          N      VIIRS          n  1.0NRT       280.3   0.9        N     1.0
# 15          N      VIIRS          n  1.0NRT       280.8   0.9        N     NaN
# 16          N      VIIRS          n  1.0NRT       299.5   9.8        D     NaN
# 17          N      VIIRS          h  1.0NRT       301.5  11.4        D     2.0
# 18          N      VIIRS          n  1.0NRT       285.4   1.6        N     2.0
# 19          N      VIIRS          n  1.0NRT       282.7   1.6        N     NaN
# 20          N      VIIRS          n  1.0NRT       284.9   1.6        N     NaN
# 21          N      VIIRS          n  1.0NRT       283.8   2.2        N     NaN
# 22          N      VIIRS          n  1.0NRT       282.8   1.0        N     NaN
# 23          N      VIIRS          n  1.0NRT       285.3   0.7        N     NaN
# 24          N      VIIRS          n  1.0NRT       288.5   1.4        N     NaN
# 25          N      VIIRS          n  1.0NRT       286.4   0.9        N     NaN
# 26          N      VIIRS          n  1.0NRT       296.3  16.6        D     NaN
# 27          N      VIIRS          n  1.0NRT       302.3  16.6        D     NaN
# 28          N      VIIRS          n  1.0NRT       299.7   7.0        D     3.0
# 29          N      VIIRS          n  1.0NRT       287.7   1.3        N     3.0
# ..        ...        ...        ...     ...         ...   ...      ...     ...
# 92          N      VIIRS          n  1.0NRT       287.7   2.4        N     NaN
# 93          N      VIIRS          n  1.0NRT       283.5   2.4        N     NaN
# 94          N      VIIRS          n  1.0NRT       284.8   2.4        N     NaN
# 95          N      VIIRS          n  1.0NRT       286.4   2.4        N     NaN
# 96          N      VIIRS          n  1.0NRT       287.7   4.6        N     NaN
# 97          N      VIIRS          n  1.0NRT       286.1   2.4        N     NaN
# 98          N      VIIRS          n  1.0NRT       286.4   2.4        N     NaN
# 99          N      VIIRS          n  1.0NRT       285.7   4.6        N     NaN
# 100         N      VIIRS          n  1.0NRT       285.0   4.4        N     NaN
# 101         N      VIIRS          n  1.0NRT       282.9  14.2        D     NaN
# 102         N      VIIRS          n  1.0NRT       281.3   7.6        D     NaN
# 103         N      VIIRS          n  1.0NRT       287.8  14.9        D     NaN
# 104         N      VIIRS          n  1.0NRT       282.3   0.9        N     NaN
# 105         N      VIIRS          n  1.0NRT       281.9   0.9        N     NaN
# 106         N      VIIRS          n  1.0NRT       280.1   1.3        N     8.0
# 107         N      VIIRS          n  1.0NRT       287.4   2.4        N     8.0
# 108         N      VIIRS          n  1.0NRT       285.3   1.4        N     NaN
# 109         N      VIIRS          n  1.0NRT       286.7   2.4        N     9.0
# 110         N      VIIRS          n  1.0NRT       281.8   1.6        N     9.0
# 111         N      VIIRS          n  1.0NRT       281.9   1.5        N    10.0
# 112         N      VIIRS          n  1.0NRT       284.7   1.1        N    10.0
# 113         N      VIIRS          n  1.0NRT       284.6   0.9        N     NaN
# 114         N      VIIRS          n  1.0NRT       283.9   1.5        N     NaN
# 115         N      VIIRS          n  1.0NRT       284.8   0.9        N     NaN
# 116         N      VIIRS          n  1.0NRT       297.8   2.7        D     NaN
# 117         N      VIIRS          n  1.0NRT       286.5   2.7        D     NaN
# 118         N      VIIRS          n  1.0NRT       287.5   4.2        D     NaN
# 119         N      VIIRS          n  1.0NRT       290.2   1.8        D     NaN
# 120         N      VIIRS          n  1.0NRT       288.5   8.0        D     NaN
# 121         N      VIIRS          n  1.0NRT       283.5  26.0        D     NaN
#
# [122 rows x 15 columns]

# %%
# This function gets the current and next values for consecutive dates
# Returns a dataframe of Latitude and longitude values for consecutive days
def get_curr_values_and_next_values(df_in):
    result = []

    # Created dataframe within test range
    data_viirs_test = []
    consecutive_days = []
    for i in range(0, len(viirs_test)):
        # start at specific latitude and longitude, for first date
        lat_i = df_in.at[(i, 'latitude')]
        long_i = df_in.at[(i, 'longitude')]
        date_i = df_in.at[(i, 'acq_date')]
#         data_viirs_test.append([lat_i, long_i, date_i])

        if (i != 0): #base case
            if date_i == df_in.at[(i - 1, 'acq_date')]:
                continue;

        # Current day df
        df_curr_day = df[df_in.acq_date == date_i]
        df_curr_day = df_curr_day.reset_index()
        df_curr_day = df_curr_day.drop(columns = "index")

        # Get the next day
        # Work with days only
        next_date = date_i + timedelta(days=1)
        df_next_day = df[df_in.acq_date == next_date]
    #     print(date_i)

        # Reset index
        df_next_day = df_next_day.reset_index()
        df_next_day = df_next_day.drop(columns = "index")

        if (len(df_next_day) == 0):
            # No values for the next day
            # Fire has to last at least a day
            continue;

        else:
            consecutive_days.append([date_i]) # add current date
            consec_days_df = pd.DataFrame(consecutive_days, columns=['date'])
            
            result.append([df_curr_day, date_i])
            result.append([df_next_day, next_date])
        
        result_df = pd.DataFrame(result, columns = ['day_df', 'date'])
        
    return result_df

# %%
consec_values = get_curr_values_and_next_values(viirs_test)
consec_values

# Drop duplicate days
consec_day_values = consec_values.drop_duplicates(subset = "date")
# Latitude and longitude values for consecutive days ==> use this to get size
consec_day_values = consec_day_values.reset_index()
consec_day_values = consec_day_values.drop(columns = "index")
consec_day_values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-0eb6df8e3d0f> in <module>()
# ----> 1 consec_values = get_curr_values_and_next_values(viirs_test)
#       2 consec_values
#       3
#       4 # Drop duplicate days
#       5 consec_day_values = consec_values.drop_duplicates(subset = "date")
#
# <ipython-input-26-86940aeca71b> in get_curr_values_and_next_values(df_in)
#      19
#      20         # Current day df
# ---> 21         df_curr_day = df[df_in.acq_date == date_i]
#      22         df_curr_day = df_curr_day.reset_index()
#      23         df_curr_day = df_curr_day.drop(columns = "index")
#
# NameError: name 'df' is not defined

# %%
consec_day_values.at[(9, "day_df")]
# Out:
#     latitude  longitude       date
# 0   48.27109 -120.73183 2019-08-29
# 1   48.25713 -120.73469 2019-08-29
# 2   48.26063 -120.73402 2019-08-29
# 3   48.25631 -120.72803 2019-08-29
# 4   48.25965 -120.72903 2019-08-29
# 5   48.26130 -120.73332 2019-08-29
# 6   48.25608 -120.73497 2019-08-29
# 7   48.25507 -120.73851 2019-08-29
# 8   48.25336 -120.73407 2019-08-29
# 9   48.25774 -120.73930 2019-08-29
# 10  48.25437 -120.73048 2019-08-29
# 11  48.25722 -120.73542 2019-08-29
# 12  48.25758 -120.73109 2019-08-29
# 13  48.25562 -120.73379 2019-08-29

# %%
def size_of_fire(df_in, day):
    size_list = [] #general location, date, size
    
    # size of range to check
    lat_long_range = 0.001
    
    day_test = df_in.at[(day, "day_df")]
    date = df_in.at[(day, "date")]
    print(day_test)

    for j in range(0, len(day_test)):
        lat_j = day_test.at[(j, 'latitude')]
        long_j = day_test.at[(j, 'longitude')]
        radius = 1
        fire_locations = []
        for k in range(j + 1, len(day_test)):
            lat_k = day_test.at[(k, 'latitude')]
            long_k = day_test.at[(k, 'longitude')]
            
            if abs(lat_j - lat_k) >= lat_long_range and abs(long_j - long_k) >= lat_long_range: #base case
                # if out of range = different fires; do nothing
                x = 0
            else:
                fire_locations.append([lat_k, long_k]) #which points in fire
                radius += 1
                print(fire_locations)
        fire_locations_df = pd.DataFrame(fire_locations, columns = ['lat', 'long'])
        size_list.append([lat_j, long_j, radius, fire_locations_df, date])
            
    size_df = pd.DataFrame(size_list, columns = ['lat', 'long', 'size', 'fire_locations_df', 'date'])           
    return size_df

size_of_fire(consec_day_values, 1)
# Out:
#    latitude  longitude       date
# 0  48.25742 -120.72633 2019-08-01
# 1  48.26073 -120.72491 2019-08-01
# 2  48.26174 -120.72616 2019-08-01
# 3  48.26184 -120.72263 2019-08-01
# [[48.26174, -120.72616000000001]]
# [[48.26184, -120.72263000000001]]
#         lat       long  size                               fire_locations_df  \
# 0  48.25742 -120.72633     2           lat       long
# 0  48.26174 -120.72616
# 1  48.26073 -120.72491     1  Empty DataFrame
# Columns: [lat, long]
# Index: []
# 2  48.26174 -120.72616     2           lat       long
# 0  48.26184 -120.72263
# 3  48.26184 -120.72263     1  Empty DataFrame
# Columns: [lat, long]
# Index: []
#
#         date
# 0 2019-08-01
# 1 2019-08-01
# 2 2019-08-01
# 3 2019-08-01

# %%
def get_size(consec_day_values, day):
    size_of_fire_day = size_of_fire(consec_day_values, day)
    for i in range(0, len(size_of_fire1)):
        lat_i = size_of_fire1.at[(i, 'lat')]
        long_i = size_of_fire1.at[(i, 'long')]
        df_i = size_of_fire1.at[(i, 'fire_locations_df')]
        print(df_i)
        if (df_i.empty == True):
            continue;
        else:
            print("do something to add size") #combine

for i in range(0, len(consec_day_values)):
    get_size(consec_day_values, i)
# Out:
#    latitude  longitude       date
# 0  48.26039 -120.72485 2019-07-31
# 1  48.53847 -120.22054 2019-07-31
# 2  48.53862 -120.23101 2019-07-31
# 3  48.53596 -120.23206 2019-07-31
# 4  48.54295 -120.23227 2019-07-31
# 5  48.53574 -120.22076 2019-07-31
# 6  48.54277 -120.22243 2019-07-31
# [[48.53862, -120.23101000000001]]
# [[48.53862, -120.23101000000001], [48.535740000000004, -120.22076000000001]]
# [[48.54295, -120.23227]]
# [[48.54295, -120.23227], [48.535740000000004, -120.22076000000001]]
# [[48.542770000000004, -120.22243]]
#         lat       long
# 0  48.26174 -120.72616
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
#         lat       long
# 0  48.26184 -120.72263
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
#    latitude  longitude       date
# 0  48.25742 -120.72633 2019-08-01
# 1  48.26073 -120.72491 2019-08-01
# 2  48.26174 -120.72616 2019-08-01
# 3  48.26184 -120.72263 2019-08-01
# [[48.26174, -120.72616000000001]]
# [[48.26184, -120.72263000000001]]
#         lat       long
# 0  48.26174 -120.72616
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
#         lat       long
# 0  48.26184 -120.72263
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
#    latitude  longitude       date
# 0  48.26644 -120.73222 2019-08-02
# 1  48.26564 -120.72642 2019-08-02
# 2  48.26310 -120.73317 2019-08-02
# 3  48.25897 -120.72832 2019-08-02
# 4  48.25819 -120.72265 2019-08-02
# [[48.265640000000005, -120.72641999999999]]
# [[48.265640000000005, -120.72641999999999], [48.2631, -120.73317]]
# [[48.25819, -120.72265]]
#         lat       long
# 0  48.26174 -120.72616
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
#         lat       long
# 0  48.26184 -120.72263
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
#    latitude  longitude       date
# 0  48.26060 -120.72910 2019-08-06
# 1  48.26500 -120.73235 2019-08-06
# 2  48.26746 -120.72578 2019-08-06
# 3  48.26989 -120.72466 2019-08-06
# 4  48.26983 -120.72842 2019-08-06
# 5  48.26381 -120.73018 2019-08-06
# [[48.26983, -120.72842]]
# [[48.26983, -120.72842]]
#         lat       long
# 0  48.26174 -120.72616
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
#         lat       long
# 0  48.26184 -120.72263
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
#     latitude  longitude       date
# 0   48.27203 -120.72083 2019-08-07
# 1   48.26957 -120.72713 2019-08-07
# 2   48.27283 -120.72604 2019-08-07
# 3   48.26711 -120.73344 2019-08-07
# 4   48.26632 -120.72825 2019-08-07
# Index: []
#         lat       long
# 0  48.26184 -120.72263
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
#    latitude  longitude       date
# 0  48.25885 -120.73291 2019-08-27
# 1  48.25939 -120.73291 2019-08-27
# 2  48.26410 -120.73628 2019-08-27
# [[48.25939, -120.73291]]
#         lat       long
# 0  48.26174 -120.72616
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
#         lat       long
# 0  48.26184 -120.72263
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
#    latitude  longitude       date
# 0  48.26533 -120.73811 2019-08-28
# 1  48.26125 -120.73445 2019-08-28
# 2  48.25800 -120.73575 2019-08-28
# 3  48.26137 -120.73659 2019-08-28
# [[48.26137, -120.73658999999999]]
# [[48.26137, -120.73658999999999]]
#         lat       long
# 0  48.26174 -120.72616
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
#         lat       long
# 0  48.26184 -120.72263
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
#     latitude  longitude       date
# 0   48.27109 -120.73183 2019-08-29
# 1   48.25713 -120.73469 2019-08-29
# 2   48.26063 -120.73402 2019-08-29
# 3   48.25631 -120.72803 2019-08-29
# 4   48.25965 -120.72903 2019-08-29
# 5   48.26130 -120.73332 2019-08-29
# 6   48.25608 -120.73497 2019-08-29
# 7   48.25507 -120.73851 2019-08-29
# 8   48.25336 -120.73407 2019-08-29
# 9   48.25774 -120.73930 2019-08-29
# 10  48.25437 -120.73048 2019-08-29
# 11  48.25722 -120.73542 2019-08-29
# 12  48.25758 -120.73109 2019-08-29
# 13  48.25562 -120.73379 2019-08-29
# [[48.25758, -120.73109]]
# [[48.26063, -120.73402]]
# [[48.26063, -120.73402], [48.25631, -120.72803]]
# [[48.26063, -120.73402], [48.25631, -120.72803], [48.25608, -120.73496999999999]]
# [[48.26063, -120.73402], [48.25631, -120.72803], [48.25608, -120.73496999999999], [48.25336, -120.73406999999999]]
# [[48.26063, -120.73402], [48.25631, -120.72803], [48.25608, -120.73496999999999], [48.25336, -120.73406999999999], [48.257740000000005, -120.7393]]
# [[48.26063, -120.73402], [48.25631, -120.72803], [48.25608, -120.73496999999999], [48.25336, -120.73406999999999], [48.257740000000005, -120.7393], [48.257220000000004, -120.73541999999999]]
# [[48.26063, -120.73402], [48.25631, -120.72803], [48.25608, -120.73496999999999], [48.25336, -120.73406999999999], [48.257740000000005, -120.7393], [48.257220000000004, -120.73541999999999], [48.25758, -120.73109]]
# [[48.26063, -120.73402], [48.25631, -120.72803], [48.25608, -120.73496999999999], [48.25336, -120.73406999999999], [48.257740000000005, -120.7393], [48.257220000000004, -120.73541999999999], [48.25758, -120.73109], [48.25562, -120.73378999999998]]
# [[48.25965, -120.72903000000001]]
# [[48.25965, -120.72903000000001], [48.2613, -120.73331999999999]]
# [[48.25965, -120.72903000000001], [48.2613, -120.73331999999999], [48.25608, -120.73496999999999]]
# [[48.25965, -120.72903000000001], [48.2613, -120.73331999999999], [48.25608, -120.73496999999999], [48.25336, -120.73406999999999]]
# [[48.25965, -120.72903000000001], [48.2613, -120.73331999999999], [48.25608, -120.73496999999999], [48.25336, -120.73406999999999], [48.25562, -120.73378999999998]]
# [[48.25608, -120.73496999999999]]
# [[48.25608, -120.73496999999999], [48.257220000000004, -120.73541999999999]]
# [[48.25608, -120.73496999999999], [48.257220000000004, -120.73541999999999], [48.25562, -120.73378999999998]]
# [[48.25336, -120.73406999999999]]
# [[48.25336, -120.73406999999999], [48.25562, -120.73378999999998]]
# [[48.25336, -120.73406999999999]]
# [[48.25336, -120.73406999999999], [48.257220000000004, -120.73541999999999]]
# [[48.25336, -120.73406999999999], [48.257220000000004, -120.73541999999999], [48.25562, -120.73378999999998]]
# [[48.257740000000005, -120.7393]]
# [[48.257740000000005, -120.7393], [48.25437, -120.73048]]
# [[48.257740000000005, -120.7393], [48.25437, -120.73048], [48.25562, -120.73378999999998]]
# [[48.25562, -120.73378999999998]]
# [[48.257220000000004, -120.73541999999999]]
# [[48.257220000000004, -120.73541999999999], [48.25758, -120.73109]]
# [[48.25758, -120.73109]]
# [[48.25758, -120.73109]]
#         lat       long
# 0  48.26174 -120.72616
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
#         lat       long
# 0  48.26184 -120.72263
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
#    latitude  longitude       date
# 0  48.26133 -120.73635 2019-09-02
# 1  48.26463 -120.73488 2019-09-02
# 2  48.26556 -120.73998 2019-09-02
# [[48.26556, -120.73998]]
#         lat       long
# 0  48.26174 -120.72616
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
#         lat       long
# 0  48.26184 -120.72263
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
#    latitude  longitude       date
# 0  48.26286 -120.73766 2019-09-03
# 1  48.25616 -120.73952 2019-09-03
# 2  48.25952 -120.73862 2019-09-03
# [[48.25952, -120.73862]]
# [[48.25952, -120.73862]]
#         lat       long
# 0  48.26174 -120.72616
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
#         lat       long
# 0  48.26184 -120.72263
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
#    latitude  longitude       date
# 0  48.25936 -120.74005 2019-09-04
# 1  48.26301 -120.73837 2019-09-04
#         lat       long
# 0  48.26174 -120.72616
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
#         lat       long
# 0  48.26184 -120.72263
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
#    latitude  longitude       date
# 0  48.26458 -120.73978 2019-09-05
#         lat       long
# 0  48.26174 -120.72616
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
#         lat       long
# 0  48.26184 -120.72263
# do something to add size
# Empty DataFrame
# Columns: [lat, long]
# Index: []
