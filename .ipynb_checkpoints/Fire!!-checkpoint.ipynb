# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
viirs = pd.read_csv("fire_nrt_V1_83401.csv")
# modis = pd.read_csv("fire_nrt_M6_83400.csv")

# %%
viirs.head()
# Out:
#    latitude  longitude  bright_ti4  scan  track    acq_date  acq_time  \
# 0  33.03452  -83.08730       318.6  0.32   0.55  2019-07-01       636
# 1  34.63658  -87.09289       304.2  0.56   0.69  2019-07-01       636
# 2  34.63654  -87.08815       304.2  0.56   0.69  2019-07-01       636
# 3  34.34694  -82.77595       306.3  0.32   0.54  2019-07-01       636
# 4  43.24686  -70.96125       301.8  0.39   0.36  2019-07-01       636
#
#   satellite instrument confidence version  bright_ti5  frp daynight
# 0         N      VIIRS          n  1.0NRT       288.2  0.9        N
# 1         N      VIIRS          n  1.0NRT       286.8  1.0        N
# 2         N      VIIRS          n  1.0NRT       287.2  1.9        N
# 3         N      VIIRS          n  1.0NRT       291.0  0.8        N
# 4         N      VIIRS          n  1.0NRT       285.4  0.6        N

# %%
# modis.head()
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0    34.010    -86.113       302.5   4.7    2.0  2019-10-01       300
# 1    33.011    -79.885       319.8   2.0    1.4  2019-10-01       300
# 2    41.464    -81.681       302.6   1.6    1.3  2019-10-01       300
# 3    32.156   -101.937       301.3   1.4    1.2  2019-10-01       435
# 4    31.937   -103.538       301.1   1.8    1.3  2019-10-01       435
#
#   satellite instrument  confidence version  bright_t31   frp daynight
# 0     Terra      MODIS          49  6.0NRT       292.1  39.1        N
# 1     Terra      MODIS          99  6.0NRT       290.9  46.1        N
# 2     Terra      MODIS          50  6.0NRT       292.5   8.0        N
# 3     Terra      MODIS          40  6.0NRT       290.3   5.8        N
# 4     Terra      MODIS          38  6.0NRT       288.8   9.1        N

# %%
# modis = modis.rename(columns = {"bright_t31": "channel_brightness"})
# viirs = viirs.rename(columns = {"bright_ti5": "channel_brightness"})

# %%
# viirs = viirs.rename(columns = {"bright_ti4": "brightness"})

# %%
# firedata = pd.concat([viirs, modis])

# %%
# firedata.head()
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0  33.03452  -83.08730       318.6  0.32   0.55  2019-07-01       636
# 1  34.63658  -87.09289       304.2  0.56   0.69  2019-07-01       636
# 2  34.63654  -87.08815       304.2  0.56   0.69  2019-07-01       636
# 3  34.34694  -82.77595       306.3  0.32   0.54  2019-07-01       636
# 4  43.24686  -70.96125       301.8  0.39   0.36  2019-07-01       636
#
#   satellite instrument confidence version  channel_brightness  frp daynight
# 0         N      VIIRS          n  1.0NRT               288.2  0.9        N
# 1         N      VIIRS          n  1.0NRT               286.8  1.0        N
# 2         N      VIIRS          n  1.0NRT               287.2  1.9        N
# 3         N      VIIRS          n  1.0NRT               291.0  0.8        N
# 4         N      VIIRS          n  1.0NRT               285.4  0.6        N

# %%
# firedata = firedata.reset_index()

# %%
# firedata.head()
# Out:
#    index  latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0      0  33.03452  -83.08730       318.6  0.32   0.55  2019-07-01       636
# 1      1  34.63658  -87.09289       304.2  0.56   0.69  2019-07-01       636
# 2      2  34.63654  -87.08815       304.2  0.56   0.69  2019-07-01       636
# 3      3  34.34694  -82.77595       306.3  0.32   0.54  2019-07-01       636
# 4      4  43.24686  -70.96125       301.8  0.39   0.36  2019-07-01       636
#
#   satellite instrument confidence version  channel_brightness  frp daynight
# 0         N      VIIRS          n  1.0NRT               288.2  0.9        N
# 1         N      VIIRS          n  1.0NRT               286.8  1.0        N
# 2         N      VIIRS          n  1.0NRT               287.2  1.9        N
# 3         N      VIIRS          n  1.0NRT               291.0  0.8        N
# 4         N      VIIRS          n  1.0NRT               285.4  0.6        N

# %%
# firedata = firedata.drop(columns = "index")

# %%
# firedata.head()
# Out:
#    latitude  longitude  brightness  scan  track    acq_date  acq_time  \
# 0  33.03452  -83.08730       318.6  0.32   0.55  2019-07-01       636
# 1  34.63658  -87.09289       304.2  0.56   0.69  2019-07-01       636
# 2  34.63654  -87.08815       304.2  0.56   0.69  2019-07-01       636
# 3  34.34694  -82.77595       306.3  0.32   0.54  2019-07-01       636
# 4  43.24686  -70.96125       301.8  0.39   0.36  2019-07-01       636
#
#   satellite instrument confidence version  channel_brightness  frp daynight
# 0         N      VIIRS          n  1.0NRT               288.2  0.9        N
# 1         N      VIIRS          n  1.0NRT               286.8  1.0        N
# 2         N      VIIRS          n  1.0NRT               287.2  1.9        N
# 3         N      VIIRS          n  1.0NRT               291.0  0.8        N
# 4         N      VIIRS          n  1.0NRT               285.4  0.6        N

# %%
# type(firedata['acq_date'][1])
# Out:
# str

# %%
viirs['acq_date'] = viirs['acq_date'].apply(lambda x: datetime.strptime(x, '%Y-%m-%d'))

# %%
viirs.head()
# Out:
#    latitude  longitude  brightness  scan  track   acq_date  acq_time  \
# 0  33.03452  -83.08730       318.6  0.32   0.55 2019-07-01       636
# 1  34.63658  -87.09289       304.2  0.56   0.69 2019-07-01       636
# 2  34.63654  -87.08815       304.2  0.56   0.69 2019-07-01       636
# 3  34.34694  -82.77595       306.3  0.32   0.54 2019-07-01       636
# 4  43.24686  -70.96125       301.8  0.39   0.36 2019-07-01       636
#
#   satellite instrument confidence version  channel_brightness  frp daynight
# 0         N      VIIRS          n  1.0NRT               288.2  0.9        N
# 1         N      VIIRS          n  1.0NRT               286.8  1.0        N
# 2         N      VIIRS          n  1.0NRT               287.2  1.9        N
# 3         N      VIIRS          n  1.0NRT               291.0  0.8        N
# 4         N      VIIRS          n  1.0NRT               285.4  0.6        N

# %%
len(viirs)
# Out:
# 239299

# %%
len(viirs.groupby(['latitude']))
# Out:
# 208360

# %%
len(viirs.groupby(['longitude']))
# Out:
# 217639
